# %% [markdown]
# <em style="text-align:center">Copyright Iván Pinar Domínguez</em>

# %% [markdown]
# #  ChatMessageHistory

# %%
from langchain_openai import ChatOpenAI
from langchain.schema import SystemMessage, HumanMessage
f = open(r'C:\Users\joseantonio.clemente\Documents\Langchain\api_key.txt')
api_key = f.read()
chat = ChatOpenAI(openai_api_key=api_key)

# %%
#Definimos el objeto de histórico de mensajes
from langchain.memory import ChatMessageHistory

history = ChatMessageHistory()

# %%
consulta = "Hola, ¿cómo estás? Necesito ayudar para reconfigurar el router"

# %%
#Vamos guardando en el objeto "history" los mensajes de usuario y los mensajes AI que queramos
history.add_user_message(consulta)

# %%
resultado = chat.invoke([HumanMessage(content=consulta)])

# %%
history.add_ai_message(resultado.content)

# %%
history
# Out:
# InMemoryChatMessageHistory(messages=[HumanMessage(content='Hola, ¿cómo estás? Necesito ayudar para reconfigurar el router', additional_kwargs={}, response_metadata={}), AIMessage(content='Hola, estoy bien gracias. ¿En qué puedo ayudarte con la reconfiguración de tu router? ¿Necesitas cambiar la contraseña, configurar el acceso remoto, o algún otro ajuste en particular? Por favor, dime cuál es el problema específico que estás teniendo para que pueda brindarte la mejor ayuda posible.', additional_kwargs={}, response_metadata={})])

# %%
history.messages
# Out:
# [HumanMessage(content='Hola, ¿cómo estás? Necesito ayudar para reconfigurar el router', additional_kwargs={}, response_metadata={}),
#  AIMessage(content='Hola, estoy bien gracias. ¿En qué puedo ayudarte con la reconfiguración de tu router? ¿Necesitas cambiar la contraseña, configurar el acceso remoto, o algún otro ajuste en particular? Por favor, dime cuál es el problema específico que estás teniendo para que pueda brindarte la mejor ayuda posible.', additional_kwargs={}, response_metadata={})]
