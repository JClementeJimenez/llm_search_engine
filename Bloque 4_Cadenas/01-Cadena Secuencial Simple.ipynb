# %% [markdown]
# <em style="text-align:center">Copyright Iván Pinar Domínguez</em>

# %% [markdown]
# ## Importar librerías e instancia de modelo de chat

# %%
from langchain.prompts import PromptTemplate, SystemMessagePromptTemplate,ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_openai import ChatOpenAI
f = open(r'C:\Users\joseantonio.clemente\Documents\Langchain\api_key.txt')
api_key = f.read()
chat = ChatOpenAI(openai_api_key=api_key)

# %% [markdown]
# ##  Creación objeto LLMChain

# %%
human_message_prompt = HumanMessagePromptTemplate.from_template(
        "Dame un nombre de compañía que sea simpático para una compañía que fabrique {producto}"
    )

# %%
chat_prompt_template = ChatPromptTemplate.from_messages([human_message_prompt])

# %%
from langchain.chains import LLMChain
chain = LLMChain(llm=chat, prompt=chat_prompt_template)
# Out:
# C:\Users\joseantonio.clemente\AppData\Local\Temp\ipykernel_14316\1544802709.py:2: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=chat, prompt=chat_prompt_template)

# %%
print(chain.invoke(input="Lavadoras"))
# Out:
# {'producto': 'Lavadoras', 'text': 'Lavadoritos Limpísimos Inc.'}

# %% [markdown]
# #  Cadena Secuencia Simple

# %%
from langchain.chains.sequential import SimpleSequentialChain

# %%
llm = ChatOpenAI(openai_api_key=api_key)

# %%
template = "Dame un simple resumen con un listado de puntos para un post de un blog acerca de {tema}"
prompt1 = ChatPromptTemplate.from_template(template)
chain_1 = LLMChain(llm=llm,prompt=prompt1)

# %%
template = "Escribe un post completo usando este resumen: {resumen}"
prompt2 = ChatPromptTemplate.from_template(template)
chain_2 = LLMChain(llm=llm,prompt=prompt2)

# %%
full_chain = SimpleSequentialChain(chains=[chain_1,chain_2],
                                  verbose=True) #verbose=True nos irá dando paso a paso lo que hace, pudiendo ver los resultados intermedios

# %%
result = full_chain.invoke(input="osasuna")
# Out:
# > Entering new SimpleSequentialChain chain...
# 1. Breve historia de Osasuna y su fundación en 1920 en Pamplona.
# 2. Logros deportivos del club, como sus participaciones en la Liga Santander.
# 3. Análisis de la afición de Osasuna, conocida por su pasión y fidelidad.
# 4. Estadio de El Sadar, reconocido por su ambiente y por ser un campo complicado para los equipos rivales.
# 5. Jugadores emblemáticos que han pasado por el club a lo largo de su historia.
# 6. Actualidad del equipo y su rendimiento en la presente temporada.
# 7. Curiosidades y datos interesantes sobre el Club Atlético Osasuna.
# 8. Opinión personal sobre la importancia de este equipo en el fútbol español.
# El Club Atlético Osasuna, fundado en 1920 en Pamplona, tiene una larga y rica historia en el fútbol español. A lo largo de los años, el equipo ha logrado importantes éxitos deportivos, incluyendo varias participaciones en la Liga Santander, la máxima categoría del fútbol español.
#
# Pero más allá de sus logros deportivos, lo que realmente destaca de Osasuna es su afición. Conocidos por su pasión y fidelidad, los seguidores rojillos llenan cada semana el estadio de El Sadar, que se ha convertido en un lugar emblemático del fútbol español. El ambiente en El Sadar es único, y muchos equipos rivales se enfrentan a un verdadero desafío al jugar en este campo complicado.
#
# A lo largo de su historia, Osasuna ha tenido jugadores emblemáticos que han dejado huella en el club. Nombres como Roberto Soldado, Patxi Puñal y Jerry Álvarez son recordados por los aficionados como auténticos ídolos del equipo.
#
# En la actualidad, Osasuna sigue compitiendo en la Liga Santander y luchando por alcanzar sus objetivos deportivos. Con un rendimiento sólido en la presente temporada, el equipo se mantiene en la parte alta de la clasificación y sigue ilusionando a sus seguidores con grandes actuaciones.
#
# Además de su éxito en el terreno de juego, el Club Atlético Osasuna cuenta con curiosidades y datos interesantes que lo hacen aún más especial. Desde su origen en 1920 hasta su ascenso a la Primera División, cada detalle de la historia de Osasuna es parte de su encanto y su identidad única.
#
# Personalmente, considero que Osasuna es un equipo fundamental en el fútbol español. Su historia, su afición y su estadio lo convierten en un club especial, que ha dejado una marca imborrable en el fútbol español. Sin duda, Osasuna es un equipo que merece ser reconocido y admirado por su pasión, su historia y su importancia en el mundo del fútbol.
#
# > Finished chain.

# %%
print(result['output'])
# Out:
# El Club Atlético Osasuna, fundado en 1920 en Pamplona, tiene una larga y rica historia en el fútbol español. A lo largo de los años, el equipo ha logrado importantes éxitos deportivos, incluyendo varias participaciones en la Liga Santander, la máxima categoría del fútbol español.
#
# Pero más allá de sus logros deportivos, lo que realmente destaca de Osasuna es su afición. Conocidos por su pasión y fidelidad, los seguidores rojillos llenan cada semana el estadio de El Sadar, que se ha convertido en un lugar emblemático del fútbol español. El ambiente en El Sadar es único, y muchos equipos rivales se enfrentan a un verdadero desafío al jugar en este campo complicado.
#
# A lo largo de su historia, Osasuna ha tenido jugadores emblemáticos que han dejado huella en el club. Nombres como Roberto Soldado, Patxi Puñal y Jerry Álvarez son recordados por los aficionados como auténticos ídolos del equipo.
#
# En la actualidad, Osasuna sigue compitiendo en la Liga Santander y luchando por alcanzar sus objetivos deportivos. Con un rendimiento sólido en la presente temporada, el equipo se mantiene en la parte alta de la clasificación y sigue ilusionando a sus seguidores con grandes actuaciones.
#
# Además de su éxito en el terreno de juego, el Club Atlético Osasuna cuenta con curiosidades y datos interesantes que lo hacen aún más especial. Desde su origen en 1920 hasta su ascenso a la Primera División, cada detalle de la historia de Osasuna es parte de su encanto y su identidad única.
#
# Personalmente, considero que Osasuna es un equipo fundamental en el fútbol español. Su historia, su afición y su estadio lo convierten en un club especial, que ha dejado una marca imborrable en el fútbol español. Sin duda, Osasuna es un equipo que merece ser reconocido y admirado por su pasión, su historia y su importancia en el mundo del fútbol.
