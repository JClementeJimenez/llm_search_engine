# %% [markdown]
# <em style="text-align:center">Copyright Iván Pinar Domínguez</em>

# %% [markdown]
# #  Modelo Secuencial Completo

# %% [markdown]
# ## Importar librerías e instancia de modelo de chat

# %%
from langchain.prompts import PromptTemplate, SystemMessagePromptTemplate,ChatPromptTemplate, HumanMessagePromptTemplate
from langchain_openai import ChatOpenAI
from langchain.chains import SequentialChain, LLMChain #importamos el SequentialChain que es el modelo completo
f = open(r'C:\Users\joseantonio.clemente\Documents\Langchain\api_key.txt')
api_key = f.read()
llm = ChatOpenAI(openai_api_key=api_key)

# %%
template1 = "Dame un resumen del rendimiento de este trabajador:\n{revision_rendimiento}"
prompt1 = ChatPromptTemplate.from_template(template1)
chain_1 = LLMChain(llm=llm,
                     prompt=prompt1,
                     output_key="resumen_revision")

#Opciones objetos runnables: chain_1= prompt1 | llm
# Out:
# C:\Users\joseantonio.clemente\AppData\Local\Temp\ipykernel_10968\3602167786.py:3: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain_1 = LLMChain(llm=llm,

# %%
template2 = "Identifica las debilidades de este trabajador dentro de de este resumen de la revisión:\n{resumen_revision}"
prompt2 = ChatPromptTemplate.from_template(template2)
chain_2 = LLMChain(llm=llm,
                     prompt=prompt2,
                     output_key="debilidades")

#Opciones objetos runnables: chain_2= prompt2 | llm

# %%
template3 = "Crea un plan de mejora para ayudar en estas debilidades:\n{debilidades}"
prompt3 = ChatPromptTemplate.from_template(template3)
chain_3 = LLMChain(llm=llm,
                     prompt=prompt3,
                     output_key="plan_mejora")

#Opciones objetos runnables: chain_3= prompt3 | llm

# %%
seq_chain = SequentialChain(chains=[chain_1,chain_2,chain_3],
                            input_variables=['revision_rendimiento'],
                            output_variables=['resumen_revision','debilidades','plan_mejora'],
                            verbose=True)

# %%
revision_rendimiento_empleado = '''
Revisión de Rendimiento del Empleado

Nombre del Empleado: Juan Pérez
Posición: Analista de Datos
Período Evaluado: Enero 2023 - Junio 2023

Fortalezas:
Juan ha demostrado un fuerte dominio de las herramientas analíticas y ha proporcionado informes detallados y precisos que han sido de gran ayuda para la toma de decisiones estratégicas. Su capacidad para trabajar en equipo y su disposición para ayudar a los demás también han sido notables. Además, ha mostrado una gran ética de trabajo y una actitud positiva en el entorno laboral.

Debilidades:
A pesar de sus muchas fortalezas, Juan ha mostrado áreas que necesitan mejoras. En particular, se ha observado que a veces tiene dificultades para manejar múltiples tareas simultáneamente, lo que resulta en retrasos en la entrega de proyectos. También ha habido ocasiones en las que la calidad del trabajo ha disminuido bajo presión. Además, se ha identificado una necesidad de mejorar sus habilidades de comunicación, especialmente en lo que respecta a la presentación de datos complejos de manera clara y concisa a los miembros no técnicos del equipo. Finalmente, se ha notado una falta de proactividad en la búsqueda de soluciones a problemas imprevistos, confiando a menudo en la orientación de sus superiores en lugar de tomar la iniciativa.
'''

# %%
results = seq_chain.invoke(revision_rendimiento_empleado)
# Out:
# > Entering new SequentialChain chain...
#
# > Finished chain.

# %%
results #Tenemos un diccionario con todos los resultados intermedios y final
# Out:
# {'revision_rendimiento': '\nRevisión de Rendimiento del Empleado\n\nNombre del Empleado: Juan Pérez\nPosición: Analista de Datos\nPeríodo Evaluado: Enero 2023 - Junio 2023\n\nFortalezas:\nJuan ha demostrado un fuerte dominio de las herramientas analíticas y ha proporcionado informes detallados y precisos que han sido de gran ayuda para la toma de decisiones estratégicas. Su capacidad para trabajar en equipo y su disposición para ayudar a los demás también han sido notables. Además, ha mostrado una gran ética de trabajo y una actitud positiva en el entorno laboral.\n\nDebilidades:\nA pesar de sus muchas fortalezas, Juan ha mostrado áreas que necesitan mejoras. En particular, se ha observado que a veces tiene dificultades para manejar múltiples tareas simultáneamente, lo que resulta en retrasos en la entrega de proyectos. También ha habido ocasiones en las que la calidad del trabajo ha disminuido bajo presión. Además, se ha identificado una necesidad de mejorar sus habilidades de comunicación, especialmente en lo que respecta a la presentación de datos complejos de manera clara y concisa a los miembros no técnicos del equipo. Finalmente, se ha notado una falta de proactividad en la búsqueda de soluciones a problemas imprevistos, confiando a menudo en la orientación de sus superiores en lugar de tomar la iniciativa.\n',
#  'resumen_revision': '\nRecomendaciones:\nPara mejorar su rendimiento, se recomienda que Juan participe en capacitaciones sobre gestión del tiempo y manejo del estrés, para ayudarlo a gestionar mejor las múltiples tareas que tiene asignadas. También sería beneficioso que trabajara en mejorar sus habilidades de comunicación, especialmente en presentaciones, para que pueda transmitir la información de manera más efectiva a su equipo. Además, se sugiere que tome la iniciativa de buscar soluciones a problemas de manera proactiva, en lugar de depender en gran medida de la orientación de sus superiores. Con estos ajustes, Juan podría mejorar su rendimiento y contribuir más positivamente al equipo en el futuro.',
#  'debilidades': '1. Gestión del tiempo y manejo del estrés: Juan tiene dificultades para manejar de manera efectiva las múltiples tareas que tiene asignadas, lo que puede afectar su rendimiento global.\n2. Habilidades de comunicación: Juan necesita mejorar sus habilidades de comunicación, especialmente en presentaciones, para poder transmitir la información de manera más efectiva a su equipo.\n3. Proactividad en la resolución de problemas: Juan tiende a depender en gran medida de la orientación de sus superiores en lugar de tomar la iniciativa de buscar soluciones por sí mismo. Esto puede limitar su autonomía y creatividad en el trabajo.',
#  'plan_mejora': 'Plan de mejora para Juan:\n\n1. Gestión del tiempo y manejo del estrés:\n- Establecer un horario de trabajo que incluya tiempos específicos para cada tarea.\n- Utilizar técnicas de gestión del tiempo como la técnica Pomodoro para mejorar la productividad.\n- Aprender a decir no a tareas adicionales que puedan afectar su carga de trabajo.\n- Practicar técnicas de relajación y mindfulness para manejar el estrés.\n\n2. Habilidades de comunicación:\n- Realizar cursos de comunicación efectiva y presentaciones en público.\n- Practicar la comunicación clara y concisa con el equipo mediante reuniones regulares.\n- Solicitar retroalimentación de colegas sobre presentaciones para mejorar.\n\n3. Proactividad en la resolución de problemas:\n- Identificar situaciones en las que pueda tomar la iniciativa para resolver problemas por sí mismo.\n- Establecer metas y objetivos claros para cada proyecto y trabajar de forma independiente para lograrlos.\n- Pedir retroalimentación a superiores sobre posibles mejoras en la resolución de problemas.'}

# %%
#Resultado final
print(results['plan_mejora'])
# Out:
# Plan de mejora para Juan:
#
# 1. Gestión del tiempo y manejo del estrés:
# - Establecer un horario de trabajo que incluya tiempos específicos para cada tarea.
# - Utilizar técnicas de gestión del tiempo como la técnica Pomodoro para mejorar la productividad.
# - Aprender a decir no a tareas adicionales que puedan afectar su carga de trabajo.
# - Practicar técnicas de relajación y mindfulness para manejar el estrés.
#
# 2. Habilidades de comunicación:
# - Realizar cursos de comunicación efectiva y presentaciones en público.
# - Practicar la comunicación clara y concisa con el equipo mediante reuniones regulares.
# - Solicitar retroalimentación de colegas sobre presentaciones para mejorar.
#
# 3. Proactividad en la resolución de problemas:
# - Identificar situaciones en las que pueda tomar la iniciativa para resolver problemas por sí mismo.
# - Establecer metas y objetivos claros para cada proyecto y trabajar de forma independiente para lograrlos.
# - Pedir retroalimentación a superiores sobre posibles mejoras en la resolución de problemas.

# %%
#Se puede accceder a los resultados intermedios:
print(results["debilidades"])
# Out:
# 1. Gestión del tiempo y manejo del estrés: Juan tiene dificultades para manejar de manera efectiva las múltiples tareas que tiene asignadas, lo que puede afectar su rendimiento global.
# 2. Habilidades de comunicación: Juan necesita mejorar sus habilidades de comunicación, especialmente en presentaciones, para poder transmitir la información de manera más efectiva a su equipo.
# 3. Proactividad en la resolución de problemas: Juan tiende a depender en gran medida de la orientación de sus superiores en lugar de tomar la iniciativa de buscar soluciones por sí mismo. Esto puede limitar su autonomía y creatividad en el trabajo.
